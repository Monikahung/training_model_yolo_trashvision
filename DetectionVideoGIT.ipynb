# %%
# Persiapan Lingkungan dan Instalasi
# !pip install -q transformers==4.41.2
# !pip install -q torch==2.3.0
# !pip install -q accelerate==0.30.1
# !pip install -q opencv-python
# !pip install -q Pillow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 61.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 111.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 907.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 112.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 94.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 57.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.8.0+cu126 requires torch==2.8.0, but you have torch 2.3.0 which is incompatible.
# torchvision 0.23.0+cu126 requires torch==2.8.0, but you have torch 2.3.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 6.5 MB/s eta 0:00:00

# %%
import cv2
import torch
from transformers import AutoProcessor, AutoModelForCausalLM
from PIL import Image

# 1. Muat Model GIT
print("Memuat model GIT, proses ini lebih cepat...")
processor = AutoProcessor.from_pretrained("microsoft/git-base-coco")
model = AutoModelForCausalLM.from_pretrained("microsoft/git-base-coco")
print("Model GIT berhasil dimuat!")

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

# 2. Definisikan Fungsi Validasi
def validate_video_with_git(video_path, required_keywords):
    """
    Validasi video dengan menghasilkan deskripsi gambar menggunakan model GIT.
    """
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Gagal membuka file video.")
        return False

    valid_frames_count = 0
    frame_interval = 1  # Proses setiap 1 frame

    frame_count = 0
    while cap.isOpened():
        ret, frame_bgr = cap.read()
        if not ret:
            break

        if frame_count % frame_interval == 0:
            frame_rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)
            pil_image = Image.fromarray(frame_rgb)

            # Pra-proses gambar
            pixel_values = processor(images=pil_image, return_tensors="pt").pixel_values.to(device)

            # Hasilkan deskripsi (caption) untuk gambar
            generated_ids = model.generate(pixel_values=pixel_values, max_length=50)
            caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip().lower()

            print(f"Frame {frame_count}: '{caption}'")

            # Analisis deskripsi untuk kata kunci yang diperlukan
            # Mengubah logika validasi: cek apakah setidaknya dua dari tiga kata kunci ada

            found_keywords = [keyword for keyword in required_keywords if keyword in caption]

            # Jika ditemukan minimal 2 dari 3 kata kunci, anggap frame valid
            is_valid_frame = len(found_keywords) >= 2

            if is_valid_frame:
                valid_frames_count += 1
            else:
                valid_frames_count = 0

            # Jika terdeteksi dalam 3 frame berturut-turut
            if valid_frames_count >= 3:
                cap.release()
                return True

        frame_count += 1

    cap.release()
    return False

# 3. Jalankan Validasi
if __name__ == "__main__":
    video_file_kertas = 'video_kertas_benar.mp4'
    video_file_daun = 'video_daun_benar.mp4'
    video_file_botol_plastik = 'video_botol_plastik_benar.mp4'
    video_file_kaleng = 'video_kaleng_benar.mp4'

    keywords_kertas = ['person', 'paper', 'yellow trash can']
    keywords_daun = ['person', 'leaves', 'green trash can']
    keywords_botol_plastik = ['person', 'plastic bottle', 'yellow trash can']
    keywords_kaleng = ['person', 'drink cans', 'yellow trash can']

    print(f"Memproses video: {video_file_kertas}...")
    valid = validate_video_with_git(video_file_kertas, keywords_kertas)

    # Validasi pengecekan video pembuangan sampah kertas
    if valid:
        print("Video Kertas dianggap valid. Misi berhasil!")
    else:
        print("Video Kertas tidak memenuhi kriteria. Misi gagal.")

    # Validasi pengecekan video pembuangan sampah daun
    print(f"\nMemproses video: {video_file_daun}...")
    valid = validate_video_with_git(video_file_daun, keywords_daun)

    if valid:
        print("Video Daun dianggap valid. Misi berhasil!")
    else:
        print("Video Daun tidak memenuhi kriteria. Misi gagal.")

    # Validasi pengecekan video pembuangan botol plastik
    print(f"\nMemproses video: {video_file_botol_plastik}...")
    valid = validate_video_with_git(video_file_botol_plastik, keywords_botol_plastik)

    if valid:
        print("Video Botol Plastik dianggap valid. Misi berhasil!")
    else:
        print("Video Botol Plastik tidak memenuhi kriteria. Misi gagal.")

    # Validasi pengecekan video pembuangan kaleng minuman
    print(f"\nMemproses video: {video_file_kaleng}...")
    valid = validate_video_with_git(video_file_kaleng, keywords_kaleng)

    if valid:
        print("Video Kaleng Minuman dianggap valid. Misi berhasil!")
    else:
        print("Video Kaleng Minuman tidak memenuhi kriteria. Misi gagal.")
# Out:
# Memuat model GIT, proses ini lebih cepat...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/503 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/707M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# Model GIT berhasil dimuat!
# Memproses video: video_kertas_benar.mp4...
# Frame 0: 'a yellow trash can with a black lid'
# Frame 1: 'a yellow trash can with a black lid'
# Frame 2: 'a yellow trash can with a black lid'
# Frame 3: 'a yellow trash can with a black lid'
# Frame 4: 'a yellow bin with a lid and a black lid'
# Frame 5: 'a yellow bin with a lid and a black lid'
# Frame 6: 'a yellow trash can with a black lid'
# Frame 7: 'a yellow trash can with a black lid'
# Frame 8: 'a yellow trash can with a lid'
# Frame 9: 'a yellow trash can with a black lid'
# Frame 10: 'a plastic bin with a lid and a plastic bag'
# Frame 11: 'a yellow trash can with a black lid'
# Frame 12: 'how to make a disposable plastic bag out of plastic'
# Frame 13: 'how to make a disposable plastic bag out of a plastic bin'
# Frame 14: 'a hand is seen filling a plastic bin with a plastic bag.'
# Frame 15: 'a hand picking up a bag of trash from a yellow trash can'
# Frame 16: 'a hand is shown with a plastic bag.'
# Frame 17: 'a person throwing a plastic bag into a recycling bin.'
# Frame 18: 'a person putting a plastic bag into a recycling bin'
# Frame 19: 'a person throwing a plastic bag into a yellow trash can'
# Frame 20: 'a person throwing a plastic bag into a yellow trash can'
# Frame 21: 'a person throwing a plastic bag into a yellow trash can.'
# Video Kertas dianggap valid. Misi berhasil!
#
# Memproses video: video_daun_benar.mp4...
# Frame 0: 'a trash can filled with plants and plastic bags.'
# Frame 1: 'a plastic bag filled with plants'
# Frame 2: 'a trash can with a plastic bag inside of it.'
# Frame 3: 'a trash can with a plastic bag inside of it.'
# Frame 4: 'a trash can with a plastic bag inside of it.'
# Frame 5: 'a trash can filled with plants and a plastic bag.'
# Frame 6: 'a trash can with a plastic bag inside of it.'
# Frame 7: 'a trash can with a plastic bag inside of it.'
# Frame 8: 'a trash can with a plastic bag inside of it.'
# Frame 9: 'a trash can with a plastic bag inside of it.'
# Frame 10: 'a trash can with a plastic bag inside of it.'
# Frame 11: 'a trash can with a plastic bag inside of it.'
# Frame 12: 'a green trash can with a plastic bag inside of it.'
# Frame 13: 'a trash can with a plastic bag inside of it.'
# Frame 14: 'a trash can with a plastic bag inside of it.'
# Frame 15: 'a trash can with a plastic bag inside of it.'
# Frame 16: 'a trash can filled with flowers and leaves.'
# Frame 17: 'a trash can filled with flowers and leaves.'
# Frame 18: 'a trash can filled with flowers and leaves.'
# Frame 19: 'a trash can filled with trash and a plastic bag.'
# Frame 20: 'a trash can filled with leaves and a plastic bag.'
# Frame 21: 'a trash can filled with leaves and a trash can.'
# Frame 22: 'a trash can filled with leaves and flowers.'
# Frame 23: 'a trash can filled with flowers and leaves.'
# Frame 24: 'a trash can filled with flowers and leaves.'
# Frame 25: 'a trash can filled with leaves and flowers.'
# Frame 26: 'a trash can filled with leaves and a plastic bag.'
# Frame 27: 'a trash can filled with leaves and a plastic bag.'
# Frame 28: 'a person picking up a plant from a trash can'
# Frame 29: 'a trash can filled with flowers.'
# Frame 30: 'a person throwing a plastic bag into a trash can'
# Frame 31: 'a person is holding a bag of flowers in a trash can.'
# Frame 32: 'a person throwing a bunch of leaves into a trash can'
# Frame 33: 'a person throwing a bunch of leaves into a trash can'
# Frame 34: 'a trash can filled with leaves and fruit.'
# Frame 35: 'a trash can filled with leaves and fruit.'
# Frame 36: 'a trash can filled with flowers and leaves.'
# Frame 37: 'a trash can filled with leaves and flowers.'
# Frame 38: 'a trash can filled with leaves and a basket of leaves.'
# Frame 39: 'a trash can filled with leaves and leaves.'
# Frame 40: 'a trash can filled with leaves and flowers.'
# Frame 41: 'a person throwing a bouquet of flowers into a trash can'
# Frame 42: 'a trash can filled with flowers and leaves.'
# Frame 43: 'a person throwing leaves into a trash can'
# Frame 44: 'a trash can filled with leaves and flowers.'
# Frame 45: 'a trash can filled with leaves and a green trash can.'
# Frame 46: 'a green trash can filled with leaves and leaves.'
# Frame 47: 'a green trash can with a bunch of leaves in it.'
# Video Daun dianggap valid. Misi berhasil!
#
# Memproses video: video_botol_plastik_benar.mp4...
# Frame 0: 'a trash can filled with trash and a plastic bottle'
# Frame 1: 'a waste bin with a plastic bottle and a plastic bottle'
# Frame 2: 'a waste bin full of trash'
# Frame 3: 'a waste bin full of trash'
# Frame 4: 'a waste bin with a plastic bottle and plastic bottles'
# Frame 5: 'a trash can filled with trash and a plastic bottle'
# Frame 6: 'a trash can filled with trash and a plastic bottle'
# Frame 7: 'a waste basket full of trash'
# Frame 8: 'a trash can filled with trash and a plastic bottle'
# Frame 9: 'a waste bin with a plastic bottle and plastic bottles'
# Frame 10: 'a waste bin with a plastic bottle and plastic bottles'
# Frame 11: 'a waste bin with a plastic bottle and plastic bottles'
# Frame 12: 'a waste bin with a plastic bottle and plastic bottles'
# Frame 13: 'a waste bin with a plastic bottle and plastic bottles'
# Frame 14: 'a waste bin with a plastic bottle and plastic bottles'
# Frame 15: 'a bin full of trash and a plastic bottle'
# Frame 16: 'a bin full of trash and a plastic bottle'
# Frame 17: 'a bin full of plastic bottles and trash'
# Frame 18: 'a plastic bin full of plastic bottles and trash'
# Frame 19: 'a plastic bottle and plastic bottles in a yellow bin'
# Frame 20: 'a plastic bottle and plastic bottles in a yellow bin'
# Frame 21: 'plastic bottles in a yellow bin'
# Frame 22: 'a man holds a plastic bottle in a yellow bin.'
# Frame 23: 'a man holds a bottle of water in a yellow bin.'
# Frame 24: 'a person holds a bottle of water in a yellow bin.'
# Frame 25: 'a person holds a bottle of water in a yellow bin.'
# Frame 26: 'a person holds a bottle of water in a yellow bin.'
# Frame 27: 'a hand holding a bottle of water and trash in a yellow bin'
# Frame 28: 'a person holds a bottle of water in a yellow bin.'
# Frame 29: 'a person throwing a bottle into a yellow bin'
# Frame 30: 'a person holds a bottle of water in a yellow bin.'
# Frame 31: 'a person holds a bottle of water in a yellow bin.'
# Frame 32: 'a person holds a bottle of water in a yellow bin.'
# Frame 33: 'a person throwing a bottle into a yellow bin'
# Frame 34: 'a person holds a bottle of water in a yellow bin.'
# Frame 35: 'a person is throwing a bottle into a yellow bin.'
# Frame 36: 'a person filling a plastic bottle with trash'
# Frame 37: 'a person is opening a plastic bottle with a plastic bag in it.'
# Frame 38: 'a person places a plastic bottle in a yellow bin.'
# Video Botol Plastik dianggap valid. Misi berhasil!
#
# Memproses video: video_kaleng_benar.mp4...
# Frame 0: 'a person throwing a piece of paper into a trash can'
# Frame 1: 'a person holds a bag of paper in a trash can'
# Frame 2: 'a man throws paper in a trash can'
# Frame 3: 'a man throws paper in a trash can'
# Frame 4: 'a person throwing a bouquet of flowers into a yellow trash can'
# Frame 5: 'a person throwing a bouquet of flowers into a trash can'
# Frame 6: 'a man in a military uniform holds a yellow trash can.'
# Frame 7: 'a man is throwing garbage in a trash can'
# Frame 8: 'a trash can with a paper bag in it'
# Frame 9: 'a person throwing a bouquet of flowers into a trash can'
# Frame 10: 'a person throwing a bouquet of flowers into a trash can'
# Frame 11: 'a person throwing a bouquet of flowers into a trash can'
# Frame 12: 'a person throwing a plastic bag into a trash can'
# Frame 13: 'a trash can with a plastic bag and a bouquet of flowers'
# Frame 14: 'a waste bin full of paper and leaves'
# Frame 15: 'a person throwing a bouquet of flowers into a trash can'
# Frame 16: 'a trash can filled with flowers and leaves'
# Frame 17: 'a person throwing garbage in a yellow trash can'
# Frame 18: 'a person throwing a bouquet of flowers into a trash can'
# Frame 19: 'a person throwing a bag of vegetables into a yellow trash can'
# Frame 20: 'a trash can full of vegetables'
# Frame 21: 'a person reaching for a trash can'
# Frame 22: 'a woman is throwing a bag of food into a trash can.'
# Frame 23: 'a woman throwing flowers into a trash can'
# Frame 24: 'a woman throwing leaves into a trash can'
# Frame 25: 'a person reaching for a trash can with a trash can.'
# Frame 26: 'a woman is cleaning a yellow trash can.'
# Frame 27: 'a woman is cleaning a trash can with a paper bag.'
# Frame 28: 'a woman throws a bag of leaves into a trash can'
# Frame 29: 'a person is cleaning a trash can with a plastic bag.'
# Frame 30: 'a person throwing a bag of leaves into a trash can'
# Frame 31: 'a person throwing a paper towel into a trash can'
# Frame 32: 'a person is opening a trash can with a paper towel.'
# Frame 33: 'a person is cleaning a yellow trash can.'
# Frame 34: 'a person throwing a paper towel into a trash can'
# Frame 35: 'a person throwing a paper towel into a trash can'
# Frame 36: 'a person throws a paper towel into a trash can'
# Frame 37: 'a person throwing a bag of trash into a trash can'
# Frame 38: 'a person throwing a bag of leaves into a trash can'
# Frame 39: 'a person throwing a bag of food into a trash can'
# Frame 40: 'a trash can full of green leaves and a person holding a paper towel'
# Frame 41: 'a trash can full of green leaves and leaves'
# Frame 42: 'a trash can full of green leaves and leaves'
# Frame 43: 'a woman cleans a yellow trash can with a paper towel in her hand.'
# Frame 44: 'a woman cleans a yellow trash can with a paper towel in her hand.'
# Frame 45: 'a woman throws a paper towel into a yellow trash can.'
# Frame 46: 'a woman cleans her hands in a trash can'
# Frame 47: 'a woman throws paper in a garbage can'
# Frame 48: 'a woman throws out a yellow trash can.'
# Frame 49: 'a trash can filled with green vegetables and a yellow fire hydrant.'
# Frame 50: 'a child throws out a bin of food.'
# Frame 51: 'a bin full of green leaves and a child throwing it into it'
# Frame 52: 'a trash can full of green leaves and leaves'
# Frame 53: 'a waste bin full of green leaves and leaves'
# Frame 54: 'a waste basket full of green leaves'
# Frame 55: 'waste waste in the city'
# Frame 56: 'a waste basket full of leaves'
# Frame 57: 'a waste basket full of leaves'
# Frame 58: 'a yellow trash can filled with green leaves'
# Frame 59: 'a yellow trash can filled with green leaves'
# Frame 60: 'trash can in the city'
# Frame 61: 'waste waste in the city'
# Frame 62: 'waste waste in the city'
# Frame 63: 'waste waste in the city'
# Frame 64: 'waste waste in the city'
# Frame 65: 'waste waste in the city'
# Frame 66: 'waste waste in the city'
# Frame 67: 'waste waste in the city'
# Frame 68: 'waste waste in the city'
# Frame 69: 'waste waste in the city'
# Frame 70: 'waste waste in the city'
# Frame 71: 'recycling bins are a great way to reduce waste'
# Frame 72: 'recycling bins are a common sight in the city.'
# Frame 73: 'a trash can full of leaves'
# Frame 74: 'a trash can full of leaves'
# Frame 75: 'a trash can full of leaves'
# Frame 76: 'a trash can full of leaves'
# Frame 77: 'a child throws leaves into a yellow trash can.'
# Frame 78: 'a child throws leaves into a yellow trash can.'
# Frame 79: 'a plastic bin full of leaves'
# Frame 80: 'a yellow trash can with a plastic bag'
# Video Kaleng Minuman tidak memenuhi kriteria. Misi gagal.
